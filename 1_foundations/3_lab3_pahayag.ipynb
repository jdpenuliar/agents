# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
# reader = PdfReader("me/linkedin.pdf")
claude_opus_response_pahayag_0 = """
Gusto ko munang magtanong sa inyong lahat — sino sa atin ang nakararanas ngayon ng hirap sa trabaho, sa bayarin, sa gastos sa araw-araw, o sa kalusugan? Maaaring hindi ninyo itataas ang kamay, pero alam nating lahat na nararamdaman natin ito. Araw-araw.
Marami sa atin — o sa mga kakilala natin — ang biglang natanggal sa trabaho. Kahapon, may sahod. Ngayon, wala na. Pero hindi humihinto ang mga bayarin. Ang upa, ang kuryente, ang pagkain sa mesa — patuloy na tumataas ang gastos kahit hindi tumataas ang kita. Para sa mga kabataan sa atin, kakasimula pa lang ninyong harapin ang buhay, pero pakiramdam ninyo ay napakabigat na agad ng lahat. At para sa mga nakatatanda — matagal na kayong nagtatrabaho, pagod na pagod na ang katawan, at minsan ay may mga karamdamang dumarating na hindi inaasahan. Ang gamot ay mahal. Ang pagpapatingin sa doktor ay mahal. At sa kabila ng lahat ng pinagsikapan ninyo, parang hindi pa rin sapat.
Sa mga ganitong oras, ang tukso ay ito: tumigil na sa pag-asa. Tumigil na sa paghingi ng tulong. Pakiramdam ng marami — sino ba ang nakikinig?
Ngayong gabi, sasagutin natin ang tanong na iyan.
Basahin natin ang sinabi ni Jesus sa Mateo 7, talata 7 at 8:
“Patuloy kayong humingi at bibigyan kayo, patuloy kayong maghanap at makakakita kayo, patuloy kayong kumatok at pagbubuksan kayo; dahil bawat isa na humihingi ay tumatanggap, at bawat isa na naghahanap ay nakakakita, at bawat isa na kumakatok ay pinagbubuksan.”
Sa talatang ito, itinuturo sa atin ni Jesus kung paano dapat tayong manalangin sa ating Ama sa langit. At pansinin natin ang salitang madalas niyang gamitin — “patuloy.” Ayon sa study note ng Bibliya mula sa jw.org, ang terminong “patuloy” ay nagpapakita ng tuloy-tuloy na pagkilos. Kaya hindi sapat ang isang beses lang na panalangin. Hindi rin natin dapat hintayin na maging desperado tayo bago tayo manalangin. Patuloy — araw-araw — kahit gaano kahirap ang ating kalagayan.
Sumang-ayon din sa puntong ito ang apostol Pablo. Tatlong salita lang ang ginamit niya sa 1 Tesalonica 5:17 — pero malalim ang aral:
“Lagi kayong manalangin.”
- All Bible quotations MUST come from the New World Translation (Bagong Sanlibutang Salin) on jw.org, specifically the Tagalog Study Bible at: https://www.jw.org/tl/library/bibliya/bibliya-para-sa-pag-aaral/aklat/
- DO NOT paraphrase, modernize, shorten, or alter the wording of any Bible verse. Quote it exactly as it appears on jw.org.
- If a verse has a study note on jw.org that adds context (e.g., explanations of Greek terms or what the verse really means), READ that study note and incorporate its insight into the talk. Cite it as "ang study note ng Bibliya sa jw.org."
- Do not invent quotations, study notes, or references. If you cannot verify the wording, fetch the page or say so.
- orignal meeting source: https://www.jw.org/finder?srcid=jwlshare&wtlocale=TG&prefer=lang&docid=202026161 
- bible source: https://www.jw.org/tl/library/bibliya/bibliya-para-sa-pag-aaral

# ASSIGNMENT DETAILS
- **Tema (Theme):** Dapat na Lagi Tayong Manalangin
- **Source:** lmd Apendise A, item #16 (under PANALANGIN)
- **Cited Scriptures:** Mateo 7:7, 8 and 1 Tesalonica 5:17
- **Teaching skill applied:** th Aralin 8 — Ilustrasyong Nakapagtuturo (use a simple, relatable illustration that reaches the heart)
- **Duration target:** approximately 5 minutes when read at a normal pace (~600–700 words in Tagalog)

# AUDIENCE & TONE
- **Language:** Tagalog (natural, conversational Tagalog — NOT stiff, NOT overly literary, NOT awkwardly translated)
- **Audience in the congregation:** mixed — young adults AND elderly
- **Audience visualized in the illustration (the people the publishers will meet in the door-to-door ministry):** people struggling with layoffs, rising bills, daily cost of living, AND health issues (medications, doctor visits, aging bodies)
- **Tone:** warm, human, sincere, pastoral — like a real person talking to friends, not an AI generating content. Use rhetorical questions, short sentences for emphasis, and natural pauses. Avoid sounding scripted or robotic.

# STRUCTURE (follow this order)
1. **Opening hook** — a rhetorical question that names the audience's real pain points: trabaho, bayarin, gastos sa araw-araw, kalusugan. Acknowledge the pain without minimizing it.
2. **Build the picture** — describe specific struggles for THREE groups: people who lost jobs, young adults starting out, and elderly facing health/medical costs and exhausted bodies. Be concrete (upa, kuryente, pagkain, gamot, doktor).
3. **Name the temptation** — the temptation to stop hoping, stop asking for help. End with a rhetorical question: "sino ba ang nakikinig?"
4. **Bridge to Scripture** — "Ngayong gabi, sasagutin natin ang tanong na iyan."
5. **Read Mateo 7:7, 8** verbatim from jw.org.
6. **Apply the verse** — introduce that this is Jesus teaching how to pray. Highlight the word "patuloy" and bring in the jw.org study note explaining that "patuloy" indicates continuous action.
7. **Read 1 Tesalonica 5:17** verbatim from jw.org ("Lagi kayong manalangin.").
8. **Apply the verse** — bring in the jw.org study note that clarifies Pablo did NOT mean praying literally without stopping, but rather seeking God's guidance in every situation, big or small.
9. **Concrete examples** — give a list of small, everyday moments where prayer applies: before applying for a job, before deciding which bill to pay first, before a doctor's appointment, before talking to a boss. Reinforce that Jehova is interested in small things too.
10. **Illustration (th Aralin 8)** — use a simple, relatable illustration. Suggested: a person calling a close friend daily, not just when they need a favor — to show what kind of relationship Jehova wants with us.
11. **Tie back to the ministry** — connect the lesson to the door-to-door work. When publishers meet someone visibly weighed down (job loss, bills, illness), they have something to offer that money can't buy: a God who listens.
12. **Closing** — "Nawa ang katotohanang ito... ay madala natin sa mga tahanang pupuntahan natin sa ministeryo."

# FORMATTING RULES
- Output ONLY the talk itself, formatted with clear paragraph breaks.
- Italicize Bible quotations.
- Include a header with the theme and cited scriptures.
- At the end, briefly indicate the approximate runtime (e.g., "~5 minuto").
- DO NOT add stage directions like "[pause here]" or "[smile]" — the speaker will handle delivery.
- DO NOT add a preamble explaining what you're about to do. Just deliver the talk.

# QUALITY CHECKS BEFORE FINALIZING
- Does the Tagalog sound natural when read aloud? Read it back mentally — would a real Filipino speaker phrase it this way?
- Is every Bible quotation word-for-word from jw.org's NWT?
- Are the transitions between sections smooth, with no abrupt jumps from a verse to commentary without a connecting sentence?
- Does each major section flow into the next with a bridging sentence?
- Are the examples specific enough to feel real (named bills, specific situations) but universal enough to apply to mixed audiences?
- Does the talk land emotionally without being manipulative or melodramatic?

# OUTPUT
Deliver the complete 5-minute Pahayag now.
"""

# %%
system_prompt
# Out:
# '\n# ROLE\nYou are a Jehovah\'s Witness preparing a 5-minute "Pahayag" (talk) for the midweek meeting (Our Christian Life and Ministry / Apostolic Life-and-Ministry Meeting). You are delivering this talk standing in front of the congregation — there will be NO demonstration, no role-play, and no co-speaker. You are simply giving a prepared talk.\n\n# SOURCE MATERIAL — STRICT RULES\n- All Bible quotations MUST come from the New World Translation (Bagong Sanlibutang Salin) on jw.org, specifically the Tagalog Study Bible at: https://www.jw.org/tl/library/bibliya/bibliya-para-sa-pag-aaral/aklat/\n- DO NOT paraphrase, modernize, shorten, or alter the wording of any Bible verse. Quote it exactly as it appears on jw.org.\n- If a verse has a study note on jw.org that adds context (e.g., explanations of Greek terms or what the verse really means), READ that study note and incorporate its insight into the talk. Cite it as "ang study note ng Bibliya sa jw.org."\n- Do not invent quotations, stud
# ...

# %%
def chat(message, history):
    messages = (
        [{"role": "system", "content": system_prompt}]
        + history
        + [{"role": "user", "content": message}]
    )
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel


class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
reply
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 reply
#
# NameError: name 'reply' is not defined

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += (
    f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
)
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = (
        f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    )
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os

model_name = "claude-sonnet-4-6"
claude = OpenAI(
    api_key=os.environ.get("ANTHROPIC_API_KEY"),  # Your Claude API key
    base_url="https://api.anthropic.com/v1/",  # the Claude API endpoint
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [
        {"role": "system", "content": evaluator_system_prompt},
        {"role": "user", "content": evaluator_user_prompt(reply, message, history)},
    ]
    try:
        response = claude.chat.completions.parse(
            model=model_name,
            messages=messages,
            response_format=Evaluation,
            max_tokens=1000,
        )
        return response.choices[0].message.parsed
    except Exception as e:
        # Avoid crashing the chat UI when structured parsing is blocked (e.g. content filter).
        return Evaluation(
            is_acceptable=False,
            feedback=f"Evaluator unavailable ({type(e).__name__}): {e}",
        )

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=False, feedback="The Agent mentioned 'data science' as an area of expertise, which is not supported by JD Penuliar's LinkedIn profile or background information. This appears to be a mix-up with the Summary section which describes Ed Donner (not JD Penuliar). The Agent should only reference skills and expertise that are actually attributed to JD Penuliar, such as software engineering, full-stack development, Python, and related technologies.")

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = (
        system_prompt
        + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    )
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = (
        [{"role": "system", "content": updated_system_prompt}]
        + history
        + [{"role": "user", "content": message}]
    )
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = (
            system_prompt
            + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
        )
    else:
        system = system_prompt
    messages = (
        [{"role": "system", "content": system}]
        + history
        + [{"role": "user", "content": message}]
    )
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply = response.choices[0].message.content

    evaluation = evaluate(reply, message, history)

    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "/Users/jdpenuliar/git_projects/udemy/master_ai_agents_in_30_days/agents/.venv/lib/python3.12/site-packages/gradio/queueing.py", line 759, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jdpenuliar/git_projects/udemy/master_ai_agents_in_30_days/agents/.venv/lib/python3.12/site-packages/gradio/route_utils.py", line 354, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
